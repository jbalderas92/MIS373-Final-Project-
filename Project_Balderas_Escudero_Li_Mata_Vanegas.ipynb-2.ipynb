# %%
from pandas import Series, DataFrame
import pandas as pd
# %pylab inline
from datetime import datetime


#make file shorter by creatting a sample file of 10,000 records
import random


filename = "GlobalLandTemperaturesByCity.csv"
#number of records in file (excludes header)
n = sum(1 for line in open(filename)) - 1 

#desired sample size
s = 100000 

#the 0-indexed header will not be included in the skip list
skip = sorted(random.sample(xrange(1,n+1),n-s))  

#create sample dataframe 
global_temp_city  = pd.read_csv(filename, skiprows=skip).dropna()

#format dt column to be a datetime value 
global_temp_city['dt'] =  pd.to_datetime(global_temp_city['dt'], format="%Y-%m-%d")


global_temp_city[0:10]
# Out:
# Populating the interactive namespace from numpy and matplotlib
# WARNING: pylab import has clobbered these variables: ['random', 'datetime']
# `%matplotlib` prevents importing * from pylab and numpy
#                     dt  AverageTemperature  AverageTemperatureUncertainty  \
# 1  1757-04-01 00:00:00               7.756                          7.117
# 2  1759-03-01 00:00:00               3.402                          3.972
# 3  1759-11-01 00:00:00               1.885                          7.407
# 4  1765-10-01 00:00:00               8.121                          0.990
# 5  1770-05-01 00:00:00              11.125                          1.804
# 6  1776-10-01 00:00:00               8.695                          3.706
# 7  1778-07-01 00:00:00              18.695                          1.680
# 8  1781-04-01 00:00:00               7.094                          3.118
# 9  1783-10-01 00:00:00               9.291                          5.299
# 10 1788-01-01 00:00:00               0.544                          2.172
#
#      City  Country Latitude Longitude
# 1   Århus  Denmark   57.05N    10.33E
# 2   Århus  Denmark   57.05N    10.33E
# 3   Århus  Denmark   57.05N    10.33E
# 4   Århus  Denmark   57.05N    10.33E
# 5   Århus  Denmark   57.05N    10.33E
# 6   Århus  Denmark   57.05N    10.33E
# 7   Århus  Denmark   57.05N    10.33E
# 8   Århus  Denmark   57.05N    10.33E
# 9   Århus  Denmark   57.05N    10.33E
# 10  Århus  Denmark   57.05N    10.33E

# %%
global_temp_city.to_csv('global_land_temp_random_2.csv')

# %%
#create dictionary to hodl temp for each year

#first create dictionary to hold temp recorded in each country by year 
yearly_temp= {}

    
for index, row in global_temp_city.iterrows():
    year = row['dt'].year
    if year in yearly_temp:
        yearly_temp[year].append(row['AverageTemperature'])
    else:
       yearly_temp[year]= [row['AverageTemperature']]

average_yearly_temp = {}

for keys in yearly_temp:
    average_temp = sum(yearly_temp[keys])/len(yearly_temp)
    average_yearly_temp[keys] = average_temp

# %%
#create new column for year and average temp for each year 
global_temp_city['year']= ''
#global_temp_city['AvgTempYear']= ''
global_temp_city[:5]
# Out:
#                    dt  AverageTemperature  AverageTemperatureUncertainty  \
# 0          1958-01-01              27.296                          0.383
# 1 1851-06-01 00:00:00              15.395                          2.428
# 2          1917-10-01               7.526                          0.168
# 3          1906-12-01              18.967                          0.848
# 4          1936-04-01              24.860                          1.215
#
#          City       Country Latitude Longitude year
# 0         Aba       Nigeria    5.63N     8.07E
# 1      Abakan        Russia   53.84N    91.36E
# 2  Abbotsford        Canada   49.03N   122.45W
# 3        Abha  Saudi Arabia   18.48N    42.25E
# 4        Abha  Saudi Arabia   18.48N    42.25E

# %%
for key, value in average_yearly_temp.iteritems() :
    #print key, value
    
    for index, row in global_temp_city.iterrows():
        if row['dt'].year == key:
            #global_temp_city['Year'].iloc[index] = key
            global_temp_city['year'][index] = key
global_temp_city[:5]
# Out:
# /Users/jonathan/Library/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/ipykernel/__main__.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#                    dt  AverageTemperature  AverageTemperatureUncertainty  \
# 0          1958-01-01              27.296                          0.383
# 1 1851-06-01 00:00:00              15.395                          2.428
# 2          1917-10-01               7.526                          0.168
# 3          1906-12-01              18.967                          0.848
# 4          1936-04-01              24.860                          1.215
#
#          City       Country Latitude Longitude  year
# 0         Aba       Nigeria    5.63N     8.07E  1958
# 1      Abakan        Russia   53.84N    91.36E  1851
# 2  Abbotsford        Canada   49.03N   122.45W  1917
# 3        Abha  Saudi Arabia   18.48N    42.25E  1906
# 4        Abha  Saudi Arabia   18.48N    42.25E  1936

# %% [markdown]
# plot(cars['wt'], cars['mpg'], marker='o', color='blue', linestyle='None')
# xlabel('Weight')
# ylabel('Miles per Gallon')
# title('Weight versus Efficiency')
# show()
